# %%
from datetime import timedelta
import matplotlib.pyplot as plt

from simplesimple import Building

COMFORT_VALUES = {"COLD": 15, "COOL": 18, "SLIGHT_COOL": 19, "NEUTRAL": 21, "SLIGHT_WARM": 24, "WARM": 26, "HOT": 28}

# %%
class Stepper:
    def __init__(self, building: Building, outside_temperature=20, heating_setpoint=18, cooling_setpoint=26):
        self.building = building
        self.outside_temperature = outside_temperature
        self.heating_setpoint = heating_setpoint
        self.cooling_setpoint = cooling_setpoint

    def step(self):
        self.building.step(self.outside_temperature, self.heating_setpoint, self.cooling_setpoint)

# %%
def plotTemp(temperature, thermal_power):
    # plot the data
    plt.plot(temperature)

    # add labels and title
    plt.xlabel('Time (minutes)')
    plt.ylabel('Temperature (Celsius)')
    plt.title('Temperature Change over Time')

    # display the plot
    plt.show()

    plt.plot(thermal_power)
    plt.xlabel('Time (minutes)')
    plt.ylabel('Power (Watts)')
    plt.title('Power Change over Time')

    plt.show()

# %%
conditioned_floor_area = 100
building = Building(
    heat_mass_capacity=165000 * conditioned_floor_area,
    heat_transmission=200,
    maximum_cooling_power=-10000,
    maximum_heating_power=10000,
    initial_building_temperature=16,
    time_step_size=timedelta(minutes=15),
    conditioned_floor_area=conditioned_floor_area
)

# sample data
# simulate one time step
print(building.current_temperature)  # returns 16
print(building.thermal_power)  # returns 0
stepper = Stepper(building)
temperature_list = []
power_list = []
for i in range(100):
    stepper.step()
    temperature_list.append(building.current_temperature)
    power_list.append(building.thermal_power)
    # print(building.current_temperature)  # returns ~16.4
    # print(building.thermal_power)  # returns 10000
plotTemp(temperature_list, power_list)
# Out:
# 16
# 0

# %%
building.thermal_power
# Out:
# 8690.000216695495

# %%
power_list
# Out:
# [10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  10000,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495,
#  8690.000216695495]

# %%
stepper.outside_temperature = 6
stepper.heating_setpoint = 23
stepper.cooling_setpoint = 26

temperature_list_20 = []
power_list_20 = []
for i in range(1000):
    stepper.step()
    temperature_list_20.append(building.current_temperature)
    power_list_20.append(building.thermal_power)

stepper.heating_setpoint = 20
for i in range(1000):
    stepper.step()
    temperature_list_20.append(building.current_temperature)
    power_list_20.append(building.thermal_power)
plotTemp(temperature_list_20, power_list_20)

# %%
# temperature_list_23 = temperature_list_23[:1000]
# power_list = power_list[:1000]

# %%
stepper.outside_temperature = 6
stepper.heating_setpoint = 23
stepper.cooling_setpoint = 26

temperature_list_23 = []
power_list_23 = []
for i in range(2000):
    stepper.step()
    temperature_list_23.append(building.current_temperature)
    power_list_23.append(building.thermal_power)
plotTemp(temperature_list_23, power_list_23)

# %%
print(power_list_20[len(power_list_20) - 1])
print(power_list_23[len(power_list_23) - 1])
# Out:
# 2800.0000000003906
# 3400.0000000001955
